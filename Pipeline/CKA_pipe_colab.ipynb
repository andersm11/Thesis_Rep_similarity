# %%
import sys
import importlib
import subprocess
import math
import torch


def install_if_colab():
    if "google.colab" in sys.modules:
        print("Running in Google Colab. Checking required libraries...")

        packages = ["moabb", "braindecode", "torch_geometric"]  # Add required libraries
        missing_packages = [pkg for pkg in packages if importlib.util.find_spec(pkg) is None]

        if missing_packages:
            print(f"Installing missing libraries: {', '.join(missing_packages)}")
            # !pip install {" ".join(missing_packages)}
        else:
            print("All required libraries are already installed.")
    else:
        print("Not running in Google Colab. No installation needed.")

install_if_colab()
# Out:
# Running in Google Colab. Checking required libraries...
# All required libraries are already installed.

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip models.zip
# Out:
# Archive:  models.zip
# replace models/ShallowAttentionNet/ShallowAttentionNet_55_182726.pth? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
import numpy as np
import os
import torch
model_direc = "models"
activation_direc = "activations"
kernel_direc = "kernels"
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda and torch.cuda.is_available() else "cpu")

# %%
import pickle
X = torch.load(path+'EEG_data/emotion_test_set.pt')
X = [sublist[0] for sublist in X]  # Extract the first tensor in each tuple
X = torch.stack(X).to(device) # Stack the tensors into a single tensor

print(X.shape)
# Out:
# torch.Size([22353, 32, 400])

# %%
import CKA_functions
importlib.reload(CKA_functions)
from CKA_functions import compute_all_model_kernels,compute_all_model_CKA,load_model_metadata,plot_cka_heatmaps
from CKA_functions import load_dataset,fix_dataset_shape,compute_cross_model_cka,display_cka_matrix,compute_multi_model_kernels,display_differences_matrix_og
from CKA_functions import compose_heat_matrix
layer_names=["sgconv","spatial","spatial_att"]
batch_size = 288
n_batches = 4
compute_all_model_kernels(model_direc,
                            activation_direc,
                            kernel_direc,X,
                            layer_names=layer_names,
                            batch_size=batch_size,
                            n_batches=n_batches,
                          device=device)
# plot_cka_heatmaps("../cka_results","../kernels")
# Out:
# ShallowSGCNNet(
#   (temporal): Conv2d(1, 10, kernel_size=(1, 25), stride=(1, 1))
#   (sgconv): SimpleGCNNet(
#     (sgconv): SGConv(37, 10, K=1)
#   )
#   (batch_norm): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): AvgPool2d(kernel_size=(1, 10), stride=(1, 10), padding=0)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=3200, out_features=3, bias=True)
# )
# saving: sgconv_batch_1.pt
# saving: sgconv_batch_2.pt
# saving: sgconv_batch_3.pt
# saving: sgconv_batch_4.pt
# saving: sgconv_batch_5.pt
# saving: sgconv_batch_6.pt
# saving: sgconv_batch_7.pt
# saving: sgconv_batch_8.pt
# saving: sgconv_batch_9.pt
# saving: sgconv_batch_10.pt
# saving: sgconv_batch_11.pt
# saving: sgconv_batch_12.pt
# saving: sgconv_batch_13.pt
# saving: sgconv_batch_14.pt
# saving: sgconv_batch_15.pt
# saving: sgconv_batch_16.pt
# saving: sgconv_batch_17.pt
# saving: sgconv_batch_18.pt
# saving: sgconv_batch_19.pt
# saving: sgconv_batch_20.pt
# saving: sgconv_batch_21.pt
# saving: sgconv_batch_22.pt
# saving: sgconv_batch_23.pt
# saving: sgconv_batch_24.pt
# saving: sgconv_batch_25.pt
# saving: sgconv_batch_26.pt
# saving: sgconv_batch_27.pt
# saving: sgconv_batch_28.pt
# saving: sgconv_batch_29.pt
# saving: sgconv_batch_30.pt
# saving: sgconv_batch_31.pt
# saving: sgconv_batch_32.pt
# saving: sgconv_batch_33.pt
# saving: sgconv_batch_34.pt
# saving: sgconv_batch_35.pt
# saving: sgconv_batch_36.pt
# saving: sgconv_batch_37.pt
# saving: sgconv_batch_38.pt
# saving: sgconv_batch_39.pt
# saving: sgconv_batch_40.pt
# saving: sgconv_batch_41.pt
# saving: sgconv_batch_42.pt
# saving: sgconv_batch_43.pt
# saving: sgconv_batch_44.pt
# saving: sgconv_batch_45.pt
# saving: sgconv_batch_46.pt
# saving: sgconv_batch_47.pt
# saving: sgconv_batch_48.pt
# saving: sgconv_batch_49.pt
# saving: sgconv_batch_50.pt
# saving: sgconv_batch_51.pt
# saving: sgconv_batch_52.pt
# saving: sgconv_batch_53.pt
# saving: sgconv_batch_54.pt
# saving: sgconv_batch_55.pt
# saving: sgconv_batch_56.pt
# saving: sgconv_batch_57.pt
# saving: sgconv_batch_58.pt
# saving: sgconv_batch_59.pt
# saving: sgconv_batch_60.pt
# saving: sgconv_batch_61.pt
# saving: sgconv_batch_62.pt
# saving: sgconv_batch_63.pt
# saving: sgconv_batch_64.pt
# saving: sgconv_batch_65.pt
# saving: sgconv_batch_66.pt
# saving: sgconv_batch_67.pt
# saving: sgconv_batch_68.pt
# saving: sgconv_batch_69.pt
# saving: sgconv_batch_70.pt
# saving: sgconv_batch_71.pt
# saving: sgconv_batch_72.pt
# saving: sgconv_batch_73.pt
# saving: sgconv_batch_74.pt
# saving: sgconv_batch_75.pt
# saving: sgconv_batch_76.pt
# saving: sgconv_batch_77.pt
# saving: sgconv_batch_78.pt
# Got layer: sgconv
# Loading batches 1-4 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 5-8 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 9-12 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 13-16 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 17-20 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 21-24 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 25-28 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 29-32 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 33-36 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 37-40 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 41-44 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 45-48 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 49-52 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 53-56 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 57-60 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 61-64 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 65-68 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 69-72 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 73-76 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Loading batches 77-80 for sgconv in activations/ShallowSGCNNet/45_100300.pth
# Saved kernels for model at kernels/ShallowSGCNNet/45_100300.pth
# Cleared all elements in activations/ShallowSGCNNet/45_100300.pth
# Added empty 'done' file to activations/ShallowSGCNNet/45_100300.pth
# ShallowSGCNNet(
#   (temporal): Conv2d(1, 10, kernel_size=(1, 25), stride=(1, 1))
#   (sgconv): SimpleGCNNet(
#     (sgconv): SGConv(37, 10, K=1)
#   )
#   (batch_norm): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): AvgPool2d(kernel_size=(1, 10), stride=(1, 10), padding=0)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=3200, out_features=3, bias=True)
# )
# saving: sgconv_batch_1.pt
# saving: sgconv_batch_2.pt
# saving: sgconv_batch_3.pt
# saving: sgconv_batch_4.pt
# saving: sgconv_batch_5.pt
# saving: sgconv_batch_6.pt
# saving: sgconv_batch_7.pt
# saving: sgconv_batch_8.pt
# saving: sgconv_batch_9.pt
# saving: sgconv_batch_10.pt
# saving: sgconv_batch_11.pt
# saving: sgconv_batch_12.pt
# saving: sgconv_batch_13.pt
# saving: sgconv_batch_14.pt
# saving: sgconv_batch_15.pt
# saving: sgconv_batch_16.pt
# saving: sgconv_batch_17.pt
# saving: sgconv_batch_18.pt
# saving: sgconv_batch_19.pt
# saving: sgconv_batch_20.pt
# saving: sgconv_batch_21.pt
# saving: sgconv_batch_22.pt
# saving: sgconv_batch_23.pt
# saving: sgconv_batch_24.pt
# saving: sgconv_batch_25.pt
# saving: sgconv_batch_26.pt
# saving: sgconv_batch_27.pt
# saving: sgconv_batch_28.pt
# saving: sgconv_batch_29.pt
# saving: sgconv_batch_30.pt
# saving: sgconv_batch_31.pt
# saving: sgconv_batch_32.pt
# saving: sgconv_batch_33.pt
# saving: sgconv_batch_34.pt
# saving: sgconv_batch_35.pt
# saving: sgconv_batch_36.pt
# saving: sgconv_batch_37.pt
# saving: sgconv_batch_38.pt
# saving: sgconv_batch_39.pt
# saving: sgconv_batch_40.pt
# saving: sgconv_batch_41.pt
# saving: sgconv_batch_42.pt
# saving: sgconv_batch_43.pt
# saving: sgconv_batch_44.pt
# saving: sgconv_batch_45.pt
# saving: sgconv_batch_46.pt
# saving: sgconv_batch_47.pt
# saving: sgconv_batch_48.pt
# saving: sgconv_batch_49.pt
# saving: sgconv_batch_50.pt
# saving: sgconv_batch_51.pt
# saving: sgconv_batch_52.pt
# saving: sgconv_batch_53.pt
# saving: sgconv_batch_54.pt
# saving: sgconv_batch_55.pt
# saving: sgconv_batch_56.pt
# saving: sgconv_batch_57.pt
# saving: sgconv_batch_58.pt
# saving: sgconv_batch_59.pt
# saving: sgconv_batch_60.pt
# saving: sgconv_batch_61.pt
# saving: sgconv_batch_62.pt
# saving: sgconv_batch_63.pt
# saving: sgconv_batch_64.pt
# saving: sgconv_batch_65.pt
# saving: sgconv_batch_66.pt
# saving: sgconv_batch_67.pt
# saving: sgconv_batch_68.pt
# saving: sgconv_batch_69.pt
# saving: sgconv_batch_70.pt
# saving: sgconv_batch_71.pt
# saving: sgconv_batch_72.pt
# saving: sgconv_batch_73.pt
# saving: sgconv_batch_74.pt
# saving: sgconv_batch_75.pt
# saving: sgconv_batch_76.pt
# saving: sgconv_batch_77.pt
# saving: sgconv_batch_78.pt
# Got layer: sgconv
# Loading batches 1-4 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 5-8 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 9-12 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 13-16 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 17-20 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 21-24 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 25-28 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 29-32 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 33-36 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 37-40 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 41-44 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 45-48 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 49-52 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 53-56 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 57-60 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 61-64 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 65-68 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 69-72 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 73-76 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Loading batches 77-80 for sgconv in activations/ShallowSGCNNet/44_77766666.pth
# Saved kernels for model at kernels/ShallowSGCNNet/44_77766666.pth
# Cleared all elements in activations/ShallowSGCNNet/44_77766666.pth
# Added empty 'done' file to activations/ShallowSGCNNet/44_77766666.pth
# ShallowSGCNNet(
#   (temporal): Conv2d(1, 10, kernel_size=(1, 25), stride=(1, 1))
#   (sgconv): SimpleGCNNet(
#     (sgconv): SGConv(37, 10, K=1)
#   )
#   (batch_norm): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): AvgPool2d(kernel_size=(1, 10), stride=(1, 10), padding=0)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=3200, out_features=3, bias=True)
# )
# saving: sgconv_batch_1.pt
# saving: sgconv_batch_2.pt
# saving: sgconv_batch_3.pt
# saving: sgconv_batch_4.pt
# saving: sgconv_batch_5.pt
# saving: sgconv_batch_6.pt
# saving: sgconv_batch_7.pt
# saving: sgconv_batch_8.pt
# saving: sgconv_batch_9.pt
# saving: sgconv_batch_10.pt
# saving: sgconv_batch_11.pt
# saving: sgconv_batch_12.pt
# saving: sgconv_batch_13.pt
# saving: sgconv_batch_14.pt
# saving: sgconv_batch_15.pt
# saving: sgconv_batch_16.pt
# saving: sgconv_batch_17.pt
# saving: sgconv_batch_18.pt
# saving: sgconv_batch_19.pt
# saving: sgconv_batch_20.pt
# saving: sgconv_batch_21.pt
# saving: sgconv_batch_22.pt
# saving: sgconv_batch_23.pt
# saving: sgconv_batch_24.pt
# saving: sgconv_batch_25.pt
# saving: sgconv_batch_26.pt
# saving: sgconv_batch_27.pt
# saving: sgconv_batch_28.pt
# saving: sgconv_batch_29.pt
# saving: sgconv_batch_30.pt
# saving: sgconv_batch_31.pt
# saving: sgconv_batch_32.pt
# saving: sgconv_batch_33.pt
# saving: sgconv_batch_34.pt
# saving: sgconv_batch_35.pt
# saving: sgconv_batch_36.pt
# saving: sgconv_batch_37.pt
# saving: sgconv_batch_38.pt
# saving: sgconv_batch_39.pt
# saving: sgconv_batch_40.pt
# saving: sgconv_batch_41.pt
# saving: sgconv_batch_42.pt
# saving: sgconv_batch_43.pt
# saving: sgconv_batch_44.pt
# saving: sgconv_batch_45.pt
# saving: sgconv_batch_46.pt
# saving: sgconv_batch_47.pt
# saving: sgconv_batch_48.pt
# saving: sgconv_batch_49.pt
# saving: sgconv_batch_50.pt
# saving: sgconv_batch_51.pt
# saving: sgconv_batch_52.pt
# saving: sgconv_batch_53.pt
# saving: sgconv_batch_54.pt
# saving: sgconv_batch_55.pt
# saving: sgconv_batch_56.pt
# saving: sgconv_batch_57.pt
# saving: sgconv_batch_58.pt
# saving: sgconv_batch_59.pt
# saving: sgconv_batch_60.pt
# saving: sgconv_batch_61.pt
# saving: sgconv_batch_62.pt
# saving: sgconv_batch_63.pt
# saving: sgconv_batch_64.pt
# saving: sgconv_batch_65.pt
# saving: sgconv_batch_66.pt
# saving: sgconv_batch_67.pt
# saving: sgconv_batch_68.pt
# saving: sgconv_batch_69.pt
# saving: sgconv_batch_70.pt
# saving: sgconv_batch_71.pt
# saving: sgconv_batch_72.pt
# saving: sgconv_batch_73.pt
# saving: sgconv_batch_74.pt
# saving: sgconv_batch_75.pt
# saving: sgconv_batch_76.pt
# saving: sgconv_batch_77.pt
# saving: sgconv_batch_78.pt
# Got layer: sgconv
# Loading batches 1-4 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 5-8 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 9-12 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 13-16 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 17-20 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 21-24 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 25-28 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 29-32 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 33-36 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 37-40 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 41-44 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 45-48 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 49-52 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 53-56 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 57-60 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 61-64 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 65-68 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 69-72 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 73-76 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Loading batches 77-80 for sgconv in activations/ShallowSGCNNet/45_44552222.pth
# Saved kernels for model at kernels/ShallowSGCNNet/45_44552222.pth
# Cleared all elements in activations/ShallowSGCNNet/45_44552222.pth
# Added empty 'done' file to activations/ShallowSGCNNet/45_44552222.pth
# ShallowSGCNNet(
#   (temporal): Conv2d(1, 10, kernel_size=(1, 25), stride=(1, 1))
#   (sgconv): SimpleGCNNet(
#     (sgconv): SGConv(37, 10, K=1)
#   )
#   (batch_norm): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): AvgPool2d(kernel_size=(1, 10), stride=(1, 10), padding=0)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=3200, out_features=3, bias=True)
# )
# saving: sgconv_batch_1.pt
# saving: sgconv_batch_2.pt
# saving: sgconv_batch_3.pt
# saving: sgconv_batch_4.pt
# saving: sgconv_batch_5.pt
# saving: sgconv_batch_6.pt
# saving: sgconv_batch_7.pt
# saving: sgconv_batch_8.pt
# saving: sgconv_batch_9.pt
# saving: sgconv_batch_10.pt
# saving: sgconv_batch_11.pt
# saving: sgconv_batch_12.pt
# saving: sgconv_batch_13.pt
# saving: sgconv_batch_14.pt
# saving: sgconv_batch_15.pt
# saving: sgconv_batch_16.pt
# saving: sgconv_batch_17.pt
# saving: sgconv_batch_18.pt
# saving: sgconv_batch_19.pt
# saving: sgconv_batch_20.pt
# saving: sgconv_batch_21.pt
# saving: sgconv_batch_22.pt
# saving: sgconv_batch_23.pt
# saving: sgconv_batch_24.pt
# saving: sgconv_batch_25.pt
# saving: sgconv_batch_26.pt
# saving: sgconv_batch_27.pt
# saving: sgconv_batch_28.pt
# saving: sgconv_batch_29.pt
# saving: sgconv_batch_30.pt
# saving: sgconv_batch_31.pt
# saving: sgconv_batch_32.pt
# saving: sgconv_batch_33.pt
# saving: sgconv_batch_34.pt
# saving: sgconv_batch_35.pt
# saving: sgconv_batch_36.pt
# saving: sgconv_batch_37.pt
# saving: sgconv_batch_38.pt
# saving: sgconv_batch_39.pt
# saving: sgconv_batch_40.pt
# saving: sgconv_batch_41.pt
# saving: sgconv_batch_42.pt
# saving: sgconv_batch_43.pt
# saving: sgconv_batch_44.pt
# saving: sgconv_batch_45.pt
# saving: sgconv_batch_46.pt
# saving: sgconv_batch_47.pt
# saving: sgconv_batch_48.pt
# saving: sgconv_batch_49.pt
# saving: sgconv_batch_50.pt
# saving: sgconv_batch_51.pt
# saving: sgconv_batch_52.pt
# saving: sgconv_batch_53.pt
# saving: sgconv_batch_54.pt
# saving: sgconv_batch_55.pt
# saving: sgconv_batch_56.pt
# saving: sgconv_batch_57.pt
# saving: sgconv_batch_58.pt
# saving: sgconv_batch_59.pt
# saving: sgconv_batch_60.pt
# saving: sgconv_batch_61.pt
# saving: sgconv_batch_62.pt
# saving: sgconv_batch_63.pt
# saving: sgconv_batch_64.pt
# saving: sgconv_batch_65.pt
# saving: sgconv_batch_66.pt
# saving: sgconv_batch_67.pt
# saving: sgconv_batch_68.pt
# saving: sgconv_batch_69.pt
# saving: sgconv_batch_70.pt
# saving: sgconv_batch_71.pt
# saving: sgconv_batch_72.pt
# saving: sgconv_batch_73.pt
# saving: sgconv_batch_74.pt
# saving: sgconv_batch_75.pt
# saving: sgconv_batch_76.pt
# saving: sgconv_batch_77.pt
# saving: sgconv_batch_78.pt
# Got layer: sgconv
# Loading batches 1-4 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 5-8 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 9-12 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 13-16 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 17-20 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 21-24 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 25-28 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 29-32 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 33-36 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 37-40 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 41-44 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 45-48 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 49-52 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 53-56 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 57-60 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 61-64 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 65-68 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 69-72 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 73-76 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Loading batches 77-80 for sgconv in activations/ShallowSGCNNet/42_182726.pth
# Saved kernels for model at kernels/ShallowSGCNNet/42_182726.pth
# Cleared all elements in activations/ShallowSGCNNet/42_182726.pth
# Added empty 'done' file to activations/ShallowSGCNNet/42_182726.pth
# ShallowSGCNNet(
#   (temporal): Conv2d(1, 10, kernel_size=(1, 25), stride=(1, 1))
#   (sgconv): SimpleGCNNet(
#     (sgconv): SGConv(37, 10, K=1)
#   )
#   (batch_norm): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): AvgPool2d(kernel_size=(1, 10), stride=(1, 10), padding=0)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=3200, out_features=3, bias=True)
# )
# saving: sgconv_batch_1.pt
# saving: sgconv_batch_2.pt
# saving: sgconv_batch_3.pt
# saving: sgconv_batch_4.pt
# saving: sgconv_batch_5.pt
# saving: sgconv_batch_6.pt
# saving: sgconv_batch_7.pt
# saving: sgconv_batch_8.pt
# saving: sgconv_batch_9.pt
# saving: sgconv_batch_10.pt
# saving: sgconv_batch_11.pt
# saving: sgconv_batch_12.pt
# saving: sgconv_batch_13.pt
# saving: sgconv_batch_14.pt
# saving: sgconv_batch_15.pt
# saving: sgconv_batch_16.pt
# saving: sgconv_batch_17.pt
# saving: sgconv_batch_18.pt
# saving: sgconv_batch_19.pt
# saving: sgconv_batch_20.pt
# saving: sgconv_batch_21.pt
# saving: sgconv_batch_22.pt
# saving: sgconv_batch_23.pt
# saving: sgconv_batch_24.pt
# saving: sgconv_batch_25.pt
# saving: sgconv_batch_26.pt
# saving: sgconv_batch_27.pt
# saving: sgconv_batch_28.pt
# saving: sgconv_batch_29.pt
# saving: sgconv_batch_30.pt
# saving: sgconv_batch_31.pt
# saving: sgconv_batch_32.pt
# saving: sgconv_batch_33.pt
# saving: sgconv_batch_34.pt
# saving: sgconv_batch_35.pt
# saving: sgconv_batch_36.pt
# saving: sgconv_batch_37.pt
# saving: sgconv_batch_38.pt
# saving: sgconv_batch_39.pt
# saving: sgconv_batch_40.pt
# saving: sgconv_batch_41.pt
# saving: sgconv_batch_42.pt
# saving: sgconv_batch_43.pt
# saving: sgconv_batch_44.pt
# saving: sgconv_batch_45.pt
# saving: sgconv_batch_46.pt
# saving: sgconv_batch_47.pt
# saving: sgconv_batch_48.pt
# saving: sgconv_batch_49.pt
# saving: sgconv_batch_50.pt
# saving: sgconv_batch_51.pt
# saving: sgconv_batch_52.pt
# saving: sgconv_batch_53.pt
# saving: sgconv_batch_54.pt
# saving: sgconv_batch_55.pt
# saving: sgconv_batch_56.pt
# saving: sgconv_batch_57.pt
# saving: sgconv_batch_58.pt
# saving: sgconv_batch_59.pt
# saving: sgconv_batch_60.pt
# saving: sgconv_batch_61.pt
# saving: sgconv_batch_62.pt
# saving: sgconv_batch_63.pt
# saving: sgconv_batch_64.pt
# saving: sgconv_batch_65.pt
# saving: sgconv_batch_66.pt
# saving: sgconv_batch_67.pt
# saving: sgconv_batch_68.pt
# saving: sgconv_batch_69.pt
# saving: sgconv_batch_70.pt
# saving: sgconv_batch_71.pt
# saving: sgconv_batch_72.pt
# saving: sgconv_batch_73.pt
# saving: sgconv_batch_74.pt
# saving: sgconv_batch_75.pt
# saving: sgconv_batch_76.pt
# saving: sgconv_batch_77.pt
# saving: sgconv_batch_78.pt
# Got layer: sgconv
# Loading batches 1-4 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 5-8 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 9-12 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 13-16 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 17-20 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 21-24 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 25-28 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 29-32 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 33-36 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 37-40 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 41-44 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 45-48 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 49-52 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 53-56 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 57-60 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 61-64 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 65-68 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 69-72 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 73-76 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Loading batches 77-80 for sgconv in activations/ShallowSGCNNet/44_4788347.pth
# Saved kernels for model at kernels/ShallowSGCNNet/44_4788347.pth
# Cleared all elements in activations/ShallowSGCNNet/44_4788347.pth
# Added empty 'done' file to activations/ShallowSGCNNet/44_4788347.pth
# ShallowSGCNNet(
#   (temporal): Conv2d(1, 10, kernel_size=(1, 25), stride=(1, 1))
#   (sgconv): SimpleGCNNet(
#     (sgconv): SGConv(37, 10, K=1)
#   )
#   (batch_norm): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): AvgPool2d(kernel_size=(1, 10), stride=(1, 10), padding=0)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=3200, out_features=3, bias=True)
# )
# saving: sgconv_batch_1.pt
# saving: sgconv_batch_2.pt
# saving: sgconv_batch_3.pt
# saving: sgconv_batch_4.pt
# saving: sgconv_batch_5.pt
# saving: sgconv_batch_6.pt
# saving: sgconv_batch_7.pt
# saving: sgconv_batch_8.pt
# saving: sgconv_batch_9.pt
# saving: sgconv_batch_10.pt
# saving: sgconv_batch_11.pt
# saving: sgconv_batch_12.pt
# saving: sgconv_batch_13.pt
# saving: sgconv_batch_14.pt
# saving: sgconv_batch_15.pt
# saving: sgconv_batch_16.pt
# saving: sgconv_batch_17.pt
# saving: sgconv_batch_18.pt
# saving: sgconv_batch_19.pt
# saving: sgconv_batch_20.pt
# saving: sgconv_batch_21.pt
# saving: sgconv_batch_22.pt
# saving: sgconv_batch_23.pt
# saving: sgconv_batch_24.pt
# saving: sgconv_batch_25.pt
# saving: sgconv_batch_26.pt
# saving: sgconv_batch_27.pt
# saving: sgconv_batch_28.pt
# saving: sgconv_batch_29.pt
# saving: sgconv_batch_30.pt
# saving: sgconv_batch_31.pt
# saving: sgconv_batch_32.pt
# saving: sgconv_batch_33.pt
# saving: sgconv_batch_34.pt
# saving: sgconv_batch_35.pt
# saving: sgconv_batch_36.pt
# saving: sgconv_batch_37.pt
# saving: sgconv_batch_38.pt
# saving: sgconv_batch_39.pt
# saving: sgconv_batch_40.pt
# saving: sgconv_batch_41.pt
# saving: sgconv_batch_42.pt
# saving: sgconv_batch_43.pt
# saving: sgconv_batch_44.pt
# saving: sgconv_batch_45.pt
# saving: sgconv_batch_46.pt
# saving: sgconv_batch_47.pt
# saving: sgconv_batch_48.pt
# saving: sgconv_batch_49.pt
# saving: sgconv_batch_50.pt
# saving: sgconv_batch_51.pt
# saving: sgconv_batch_52.pt
# saving: sgconv_batch_53.pt
# saving: sgconv_batch_54.pt
# saving: sgconv_batch_55.pt
# saving: sgconv_batch_56.pt
# saving: sgconv_batch_57.pt
# saving: sgconv_batch_58.pt
# saving: sgconv_batch_59.pt
# saving: sgconv_batch_60.pt
# saving: sgconv_batch_61.pt
# saving: sgconv_batch_62.pt
# saving: sgconv_batch_63.pt
# saving: sgconv_batch_64.pt
# saving: sgconv_batch_65.pt
# saving: sgconv_batch_66.pt
# saving: sgconv_batch_67.pt
# saving: sgconv_batch_68.pt
# saving: sgconv_batch_69.pt
# saving: sgconv_batch_70.pt
# saving: sgconv_batch_71.pt
# saving: sgconv_batch_72.pt
# saving: sgconv_batch_73.pt
# saving: sgconv_batch_74.pt
# saving: sgconv_batch_75.pt
# saving: sgconv_batch_76.pt
# saving: sgconv_batch_77.pt
# saving: sgconv_batch_78.pt
# Got layer: sgconv
# Loading batches 1-4 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 5-8 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 9-12 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 13-16 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 17-20 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 21-24 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 25-28 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 29-32 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 33-36 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 37-40 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 41-44 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 45-48 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 49-52 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 53-56 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 57-60 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 61-64 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 65-68 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 69-72 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 73-76 for sgconv in activations/ShallowSGCNNet/44_47456655.pth
# Loading batches 77-80 for sgconv in activations/ShallowSGCNNet/44_47456655.pth

# %%
from CKA_functions import compute_all_model_CKA
compute_all_model_CKA(kernel_direc,"cka_results")
